# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Here im loading my datasets
Age_df = pd.read_excel('../Final_proj_Data/Table 1-01.xlsx', index_col = None)

# %%
Age_df2 = pd.read_excel('../Final_proj_Data/Table 2-01.xlsx', index_col = None)

# %%
#Resizing data sets
Age_df = Age_df[6:50]
Age_df2 = Age_df2[5:50]

# %%
#here im renaming the columns in the data sets
Age_df.columns=[['Age', 'Total' ,'None', '1st - 4th grade', '5th - 6th grade', '7th - 8th grade', '9th grade', '10th grade', '11th grade','High school graduate','Some college no degree', "Associate's degree, occupational", "Associate's degree, academic", "Bachelor's degree", "Master's degree", "Professional degree", "Doctoral degree"]]
Age_df2.columns = [['Total','',"None - 8th grade", '9th - 11th grade', 'High school graduate', 'Some college no degree', "Associate's degree", "Bachelor's degree", "Master's degree", "Professional degree", "Doctoral degree"]]

# %%
Age_df.index = Age_df.Age

# %%
Age_df = Age_df.drop('Age', 1)

# %%
Age_df
# Out:
#                       Total None 1st - 4th grade 5th - 6th grade  \
# Age
# .18 years and over   239341  904            1751            3355
# ..18 to 24 years      30054   78              52             139
# .25 years and over   209287  826            1699            3217
# ..25 to 29 years      21486   25              75             212
# ..30 to 34 years      20980   79             106             269
# ..35 to 39 years      19411   91             141             368
# ..40 to 44 years      20379   70             106             403
# ..45 to 49 years      20665   56             153             302
# ..50 to 54 years      22233   80             176             313
# ..55 to 59 years      21156   73             130             271
# ..60 to 64 years      18470   79             160             227
# ..65 to 69 years      14931   51             150             198
# ..70 to 74 years      10811   47             129             187
# ..75 years and over   18766  175             372             467
# Male                    NaN  NaN             NaN             NaN
# .18 years and over   115880  423             850            1733
# ..18 to 24 years      15288   54              35              99
# .25 years and over   100592  370             814            1634
# ..25 to 29 years      10831   20              33             125
# ..30 to 34 years      10386   33              65             147
# ..35 to 39 years       9562   43              69             204
# ..40 to 44 years      10030   41              54             230
# ..45 to 49 years      10145   25             102             174
# ..50 to 54 years      10787   58              99             154
# ..55 to 59 years      10252   37              60             138
# ..60 to 64 years       8836   27              74             106
# ..65 to 69 years       7065   13              54              86
# ..70 to 74 years       4981   14              61              85
# ..75 years and over    7716   61             144             184
# Female                  NaN  NaN             NaN             NaN
# .18 years and over   123461  480             902            1623
# ..18 to 24 years      14766   24              17              40
# .25 years and over   108695  456             885            1583
# ..25 to 29 years      10655    5              42              87
# ..30 to 34 years      10594   46              41             122
# ..35 to 39 years       9848   49              72             164
# ..40 to 44 years      10348   29              53             173
# ..45 to 49 years      10520   31              51             128
# ..50 to 54 years      11446   23              77             159
# ..55 to 59 years      10905   36              70             133
# ..60 to 64 years       9635   52              86             121
# ..65 to 69 years       7866   38              96             112
# ..70 to 74 years       5830   33              68             103
# ..75 years and over   11049  114             228             282
#
#                     7th - 8th grade 9th grade 10th grade 11th grade  \
# Age
# .18 years and over             4369      3773       4711      10646
# ..18 to 24 years                198       313        599       3673
# .25 years and over             4171      3460       4112       6973
# ..25 to 29 years                204       319        362        772
# ..30 to 34 years                262       399        377        789
# ..35 to 39 years                287       312        376        642
# ..40 to 44 years                286       349        322        611
# ..45 to 49 years                298       351        319        673
# ..50 to 54 years                354       351        394        734
# ..55 to 59 years                327       291        357        683
# ..60 to 64 years                423       207        307        481
# ..65 to 69 years                391       193        346        451
# ..70 to 74 years                308       183        316        331
# ..75 years and over            1030       506        636        805
# Male                            NaN       NaN        NaN        NaN
# .18 years and over             2246      1884       2396       5708
# ..18 to 24 years                119       196        335       2055
# .25 years and over             2128      1688       2061       3654
# ..25 to 29 years                108       153        203        424
# ..30 to 34 years                131       174        208        448
# ..35 to 39 years                164       182        198        384
# ..40 to 44 years                183       165        185        324
# ..45 to 49 years                157       193        182        411
# ..50 to 54 years                194       176        214        379
# ..55 to 59 years                171       126        213        387
# ..60 to 64 years                190       120        137        265
# ..65 to 69 years                172        90        150        184
# ..70 to 74 years                183        83        163        140
# ..75 years and over             475       225        207        309
# Female                          NaN       NaN        NaN        NaN
# .18 years and over             2122      1889       2315       4937
# ..18 to 24 years                 79       117        265       1618
# .25 years and over             2043      1772       2051       3319
# ..25 to 29 years                 96       166        159        348
# ..30 to 34 years                131       224        169        342
# ..35 to 39 years                123       130        178        258
# ..40 to 44 years                103       183        137        287
# ..45 to 49 years                141       157        137        262
# ..50 to 54 years                161       175        179        356
# ..55 to 59 years                156       165        144        296
# ..60 to 64 years                233        87        170        216
# ..65 to 69 years                220       103        195        267
# ..70 to 74 years                125       100        153        191
# ..75 years and over             554       282        429        497
#
#                     High school graduate Some college no degree  \
# Age
# .18 years and over                 70919                  46484
# ..18 to 24 years                    8679                  11565
# .25 years and over                 62240                  34919
# ..25 to 29 years                    5699                   4345
# ..30 to 34 years                    5342                   3438
# ..35 to 39 years                    4994                   3126
# ..40 to 44 years                    5250                   3276
# ..45 to 49 years                    6139                   3277
# ..50 to 54 years                    6855                   3631
# ..55 to 59 years                    6901                   3620
# ..60 to 64 years                    5721                   3106
# ..65 to 69 years                    4653                   2729
# ..70 to 74 years                    3809                   1802
# ..75 years and over                 6877                   2568
# Male                                 NaN                    NaN
# .18 years and over                 35514                  22085
# ..18 to 24 years                    4796                   5628
# .25 years and over                 30718                  16457
# ..25 to 29 years                    3295                   2202
# ..30 to 34 years                    3029                   1764
# ..35 to 39 years                    2821                   1525
# ..40 to 44 years                    2813                   1594
# ..45 to 49 years                    3142                   1458
# ..50 to 54 years                    3470                   1646
# ..55 to 59 years                    3445                   1760
# ..60 to 64 years                    2652                   1446
# ..65 to 69 years                    2075                   1291
# ..70 to 74 years                    1579                    747
# ..75 years and over                 2399                   1024
# Female                               NaN                    NaN
# .18 years and over                 35405                  24399
# ..18 to 24 years                    3883                   5937
# .25 years and over                 31522                  18462
# ..25 to 29 years                    2404                   2143
# ..30 to 34 years                    2313                   1674
# ..35 to 39 years                    2173                   1601
# ..40 to 44 years                    2437                   1681
# ..45 to 49 years                    2997                   1819
# ..50 to 54 years                    3385                   1985
# ..55 to 59 years                    3457                   1860
# ..60 to 64 years                    3069                   1660
# ..65 to 69 years                    2578                   1438
# ..70 to 74 years                    2230                   1055
# ..75 years and over                 4478                   1544
#
#                     Associate's degree, occupational  \
# Age
# .18 years and over                              9763
# ..18 to 24 years                                 632
# .25 years and over                              9131
# ..25 to 29 years                                 913
# ..30 to 34 years                                 952
# ..35 to 39 years                                 943
# ..40 to 44 years                                1007
# ..45 to 49 years                                 984
# ..50 to 54 years                                1067
# ..55 to 59 years                                1022
# ..60 to 64 years                                 819
# ..65 to 69 years                                 563
# ..70 to 74 years                                 280
# ..75 years and over                              581
# Male                                             NaN
# .18 years and over                              4470
# ..18 to 24 years                                 282
# .25 years and over                              4188
# ..25 to 29 years                                 401
# ..30 to 34 years                                 463
# ..35 to 39 years                                 445
# ..40 to 44 years                                 446
# ..45 to 49 years                                 473
# ..50 to 54 years                                 524
# ..55 to 59 years                                 520
# ..60 to 64 years                                 371
# ..65 to 69 years                                 222
# ..70 to 74 years                                 115
# ..75 years and over                              208
# Female                                           NaN
# .18 years and over                              5293
# ..18 to 24 years                                 350
# .25 years and over                              4943
# ..25 to 29 years                                 512
# ..30 to 34 years                                 489
# ..35 to 39 years                                 498
# ..40 to 44 years                                 561
# ..45 to 49 years                                 510
# ..50 to 54 years                                 542
# ..55 to 59 years                                 502
# ..60 to 64 years                                 449
# ..65 to 69 years                                 341
# ..70 to 74 years                                 165
# ..75 years and over                              373
#
#                     Associate's degree, academic Bachelor's degree  \
# Age
# .18 years and over                         12637             45176
# ..18 to 24 years                             978              2920
# .25 years and over                         11659             42256
# ..25 to 29 years                            1245              5687
# ..30 to 34 years                            1284              4869
# ..35 to 39 years                            1241              4236
# ..40 to 44 years                            1297              4733
# ..45 to 49 years                            1172              4553
# ..50 to 54 years                            1453              4362
# ..55 to 59 years                            1275              3762
# ..60 to 64 years                            1044              3430
# ..65 to 69 years                             674              2484
# ..70 to 74 years                             372              1669
# ..75 years and over                          602              2471
# Male                                         NaN               NaN
# .18 years and over                          5195             21300
# ..18 to 24 years                             411              1201
# .25 years and over                          4784             20099
# ..25 to 29 years                             514              2710
# ..30 to 34 years                             566              2192
# ..35 to 39 years                             497              1850
# ..40 to 44 years                             553              2206
# ..45 to 49 years                             458              2155
# ..50 to 54 years                             581              2075
# ..55 to 59 years                             492              1668
# ..60 to 64 years                             468              1790
# ..65 to 69 years                             280              1342
# ..70 to 74 years                             171               877
# ..75 years and over                          204              1233
# Female                                       NaN               NaN
# .18 years and over                          7442             23876
# ..18 to 24 years                             568              1719
# .25 years and over                          6875             22157
# ..25 to 29 years                             730              2977
# ..30 to 34 years                             718              2677
# ..35 to 39 years                             744              2386
# ..40 to 44 years                             744              2527
# ..45 to 49 years                             714              2398
# ..50 to 54 years                             872              2287
# ..55 to 59 years                             783              2094
# ..60 to 64 years                             576              1639
# ..65 to 69 years                             393              1141
# ..70 to 74 years                             201               792
# ..75 years and over                          398              1238
#
#                     Master's degree Professional degree Doctoral degree
# Age
# .18 years and over            17960                3174            3719
# ..18 to 24 years                187                  26              16
# .25 years and over            17772                3148            3703
# ..25 to 29 years               1262                 173             192
# ..30 to 34 years               2136                 361             316
# ..35 to 39 years               1947                 359             346
# ..40 to 44 years               1969                 294             405
# ..45 to 49 years               1799                 280             312
# ..50 to 54 years               1735                 335             393
# ..55 to 59 years               1690                 382             372
# ..60 to 64 years               1761                 336             368
# ..65 to 69 years               1371                 261             416
# ..70 to 74 years                958                 148             272
# ..75 years and over            1146                 218             311
# Male                            NaN                 NaN             NaN
# .18 years and over             7898                1833            2343
# ..18 to 24 years                 52                  13              14
# .25 years and over             7846                1821            2329
# ..25 to 29 years                478                  70              93
# ..30 to 34 years                829                 170             168
# ..35 to 39 years                833                 181             166
# ..40 to 44 years                831                 161             245
# ..45 to 49 years                847                 180             189
# ..50 to 54 years                822                 164             232
# ..55 to 59 years                733                 258             245
# ..60 to 64 years                768                 173             248
# ..65 to 69 years                621                 176             308
# ..70 to 74 years                465                 110             188
# ..75 years and over             618                 177             247
# Female                          NaN                 NaN             NaN
# .18 years and over            10061                1341            1376
# ..18 to 24 years                135                  14               2
# .25 years and over             9926                1327            1374
# ..25 to 29 years                784                 103              99
# ..30 to 34 years               1307                 192             148
# ..35 to 39 years               1113                 178             180
# ..40 to 44 years               1138                 133             160
# ..45 to 49 years                951                 100             122
# ..50 to 54 years                912                 171             161
# ..55 to 59 years                957                 124             128
# ..60 to 64 years                993                 163             119
# ..65 to 69 years                750                  85             108
# ..70 to 74 years                492                  38              84
# ..75 years and over             528                  41              63

# %%
#Munging data so subsets of data are seperated
M_Age_df = Age_df[15:29]

# %%
W_Age_df = Age_df[31:50]

# %%
T_Age_df = Age_df[0:14]

# %%
W_Age_df

# %%
#Here im ploting the munged data
W_Age_Plot = W_Age_df.plot(kind='bar')
#Here im labeling the "tickmarks" or sets of bars on the x axis
labels = [item.get_text() for item in W_Age_Plot.get_xticklabels()]
labels[0] = '18 to 24 years'
labels[1] =  '25 years and over'
labels[2] = '25 to 29 years'
labels[3] = '30 to 34 years'
labels[4] = '35 to 39 years'
labels[5] = '40 to 44 years'
labels[6] = '45 to 49 years'
labels[7] = '50 to 54 years'
labels[8] = '55 to 59 years'
labels[9] = '60 to 64 years'
labels[10] = "65 to 69 years"
labels[11] = "70 to 74 years"
labels[12] = "75 years and over"
W_Age_Plot.set_xticklabels(labels)
plt.show()

# %%
T_Age_Plot = T_Age_df.plot(kind='bar')
labels = [item.get_text() for item in T_Age_Plot.get_xticklabels()]
labels[0] = '18 to 24 years'
labels[1] =  '25 years and over'
labels[2] = '25 to 29 years'
labels[3] = '30 to 34 years'
labels[4] = '35 to 39 years'
labels[5] = '40 to 44 years'
labels[6] = '45 to 49 years'
labels[7] = '50 to 54 years'
labels[8] = '55 to 59 years'
labels[9] = '60 to 64 years'
labels[10] = "65 to 69 years"
labels[11] = "70 to 74 years"
labels[12] = "75 years and over"
T_Age_Plot.set_xticklabels(labels)
plt.show()

# %%
M_Age_Plot = M_Age_df.plot(kind='bar')
labels = [item.get_text() for item in M_Age_Plot.get_xticklabels()]
labels[0] = '18 to 24 years'
labels[1] =  '25 years and over'
labels[2] = '25 to 29 years'
labels[3] = '30 to 34 years'
labels[4] = '35 to 39 years'
labels[5] = '40 to 44 years'
labels[6] = '45 to 49 years'
labels[7] = '50 to 54 years'
labels[8] = '55 to 59 years'
labels[9] = '60 to 64 years'
labels[10] = "65 to 69 years"
labels[11] = "70 to 74 years"
labels[12] = "75 years and over"
M_Age_Plot.set_xticklabels(labels)
plt.show()

# %%
plt.pie(M_Age_df.Total, labels, shadow=True, startangle=90)
plt.legend(title="The Legend")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-79-687301265503> in <module>()
#       1 labels = 'Total' ,'None', '1st - 4th grade', '5th - 6th grade', '7th - 8th grade', '9th grade', '10th grade', '11th grade','High school graduate','Some college no degree', "Associate's degree, occupational", "Associate's degree, academic", "Bachelor's degree", "Master's degree", "Professional degree", "Doctoral degree"
# ----> 2 plt.pie(M_Age_df.Total, labels, shadow=True, startangle=90)
#       3 plt.legend(title="The Legend")
#       4 plt.show()
#
# /Users/andershornor/anaconda/lib/python3.4/site-packages/matplotlib/pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, hold)
#    3079                      labeldistance=labeldistance, startangle=startangle,
#    3080                      radius=radius, counterclock=counterclock,
# -> 3081                      wedgeprops=wedgeprops, textprops=textprops)
#    3082         draw_if_interactive()
#    3083     finally:
#
# /Users/andershornor/anaconda/lib/python3.4/site-packages/matplotlib/axes/_axes.py in pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops)
#    2428             explode = [0] * len(x)
#    2429         assert(len(x) == len(labels))
# -> 2430         assert(len(x) == len(explode))
#    2431         if colors is None:
#    2432             colors = ('b', 'g', 'r', 'c', 'm', 'y', 'k', 'w')
#
# AssertionError:

# %%
M_Age_Pie= M_Age_df.Total.plot(kind = 'pie', labels = ('Total' ,'None', '1st - 4th grade', '5th - 6th grade', '7th - 8th grade', '9th grade', '10th grade', '11th grade','High school graduate','Some college no degree', "Associate's degree, occupational", "Associate's degree, academic", "Bachelor's degree", "Master's degree", "Professional degree", "Doctoral degree"), subplots=True, autopct='%.2f',shadow=True, startangle=90, fontsize=10, figsize=(20, 20))
plt.legend(title="The Legend")
plt.tight_layout()
plt.show()
# Out:
# /Users/andershornor/anaconda/lib/python3.4/site-packages/matplotlib/tight_layout.py:225: UserWarning: tight_layout : falling back to Agg renderer
#   warnings.warn("tight_layout : falling back to Agg renderer")

# %%
def plot_shit (Input_df) :
    for r in  Input_df:
        r = Input_df
        d = r.index[1]
        r.d.plot(kind = 'pie')
    plt.show()

# %%
plot_shit(M_Age_df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-105-679056319f79> in <module>()
# ----> 1 plot_shit(M_Age_df)
#
# <ipython-input-104-38d791e1b7f4> in plot_shit(Input_df)
#       3         r = Input_df
#       4         d = r.index[1]
# ----> 5         r.d.plot(kind = 'pie')
#       6     plt.show()
#
# /Users/andershornor/anaconda/lib/python3.4/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2244                 return self[name]
#    2245             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 2246                                  (type(self).__name__, name))
#    2247
#    2248     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'd'
