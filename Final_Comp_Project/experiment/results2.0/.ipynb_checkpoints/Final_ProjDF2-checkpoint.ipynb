# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Here im loading my datasets
Age_df = pd.read_excel('../Final_proj_Data/Table 1-01.xlsx', index_col = None)

# %%
Age_df2 = pd.read_excel('../Final_proj_Data/Table 2-01.xlsx', index_col = None)

# %%
#Resizing data sets
Age_df = Age_df[6:50]
Age_df2 = Age_df2[5:50]

# %%
#here im renaming the columns in the data sets
Age_df.columns=[['Age', 'Total' ,'None', '1st - 4th grade', '5th - 6th grade', '7th - 8th grade', '9th grade', '10th grade', '11th grade','High school graduate','Some college no degree', "Associate's degree, occupational", "Associate's degree, academic", "Bachelor's degree", "Master's degree", "Professional degree", "Doctoral degree"]]
Age_df2.columns = [['Total','',"None - 8th grade", '9th - 11th grade', 'High school graduate', 'Some college no degree', "Associate's degree", "Bachelor's degree", "Master's degree", "Professional degree", "Doctoral degree"]]

# %%
Age_df2
# Out:
#                                        Total         None - 8th grade  \
# 5                                      Total  209287             9913
# 6                                        NaN     NaN              NaN
# 7                             Marital Status     NaN              NaN
# 8                    .Married Spouse Present  121369             5201
# 9      .Married Spouse Absent, not separated    3303              423
# 10                                .Separated    5064              410
# 11                                  .Widowed   14167             1489
# 12                                 .Divorced   25088              772
# 13                            .Never Married   40296             1617
# 14                                       NaN     NaN              NaN
# 15                    Household Relationship     NaN              NaN
# 16                       .Family householder     NaN              NaN
# 17                  ..Married spouse present   58633             2249
# 18                ..Other family householder   19294              986
# 19                    .Nonfamily householder     NaN              NaN
# 20                            ..Living alone   32390             1398
# 21                ..Living with nonrelatives    6387              189
# 22                  .Relative of householder     NaN              NaN
# 23                                  ..Spouse   58506             2411
# 24                                   ..Other   22456             2013
# 25                              .Nonrelative   11622              666
# 26                                       NaN     NaN              NaN
# 27  Citizenship, Nativity, and Year of Entry     NaN              NaN
# 28                                    .Total     NaN              NaN
# 29                                  ..Native  174004             3893
# 30                            ..Foreign Born   35283             6020
# 31                                   .Native     NaN              NaN
# 32                     ..Native Parentage /2  158358             3405
# 33           ..Foreign or Mixed Parentage /3   15646              487
# 34                             .Foreign Born     NaN              NaN
# 35                     ..Naturalized Citizen   17597             1859
# 36                           ..Not a Citizen   17686             4161
# 37                           ..Year of entry     NaN              NaN
# 38                           ..2000 or later   12775             2122
# 39                               ..1990-1999    9133             1556
# 40                               ..1980-1989    6825             1165
# 41                               ..1970-1979    3808              730
# 42                             ..Before 1970    2741              448
# 43                                       NaN     NaN              NaN
# 44                        Labor Force Status     NaN              NaN
# 45                                  Employed  126655             3957
# 46                                Unemployed    7687              309
# 47               Not in civilian labor force   74946             5646
# 48                                       NaN     NaN              NaN
# 49      Occupation (Employed Civilians Only)  126655           3957.3
#
#    9th - 11th grade High school graduate Some college no degree  \
# 5             14545                62240                  34919
# 6               NaN                  NaN                    NaN
# 7               NaN                  NaN                    NaN
# 8              6834                34289                  18935
# 9               328                  936                    446
# 10              615                 1659                    872
# 11             1604                 5459                   2073
# 12             1782                 7940                   5264
# 13             3383                11957                   7329
# 14              NaN                  NaN                    NaN
# 15              NaN                  NaN                    NaN
# 16              NaN                  NaN                    NaN
# 17             3055                15447                   9963
# 18             2000                 5995                   4075
# 19              NaN                  NaN                    NaN
# 20             2433                 9780                   5869
# 21              365                 1475                   1223
# 22              NaN                  NaN                    NaN
# 23             3345                17206                   8460
# 24             2381                 8701                   3515
# 25              965                 3637                   1815
# 26              NaN                  NaN                    NaN
# 27              NaN                  NaN                    NaN
# 28              NaN                  NaN                    NaN
# 29            10701                53395                  31421
# 30             3844                 8845                   3498
# 31              NaN                  NaN                    NaN
# 32             9757                49259                  28750
# 33              944                 4137                   2671
# 34              NaN                  NaN                    NaN
# 35             1238                 4480                   2131
# 36             2606                 4365                   1367
# 37              NaN                  NaN                    NaN
# 38             1444                 3003                   1138
# 39             1122                 2369                    837
# 40              719                 1801                    788
# 41              319                  919                    394
# 42              240                  752                    342
# 43              NaN                  NaN                    NaN
# 44              NaN                  NaN                    NaN
# 45             6096                33570                  20788
# 46              838                 2602                   1511
# 47             7611                26068                  12620
# 48              NaN                  NaN                    NaN
# 49           6096.4              33570.2                20788.2
#
#    Associate's degree Bachelor's degree Master's degree Professional degree  \
# 5               20790             42256           17772                3148
# 6                 NaN               NaN             NaN                 NaN
# 7                 NaN               NaN             NaN                 NaN
# 8               12294             26535           12378                2246
# 9                 227               578             263                  25
# 10                496               712             222                  37
# 11               1057              1571             733                 102
# 12               3069              4169            1521                 253
# 13               3648              8691            2655                 485
# 14                NaN               NaN             NaN                 NaN
# 15                NaN               NaN             NaN                 NaN
# 16                NaN               NaN             NaN                 NaN
# 17               5957             13321            6068                1136
# 18               2255              2753             974                 145
# 19                NaN               NaN             NaN                 NaN
# 20               3079              6185            2576                 448
# 21                699              1705             561                  75
# 22                NaN               NaN             NaN                 NaN
# 23               6004             12675            6147                1072
# 24               1774              3129             705                 137
# 25               1023              2488             742                 135
# 26                NaN               NaN             NaN                 NaN
# 27                NaN               NaN             NaN                 NaN
# 28                NaN               NaN             NaN                 NaN
# 29              18598             35732           14825                2672
# 30               2193              6524            2948                 475
# 31                NaN               NaN             NaN                 NaN
# 32              16949             32155           13309                2313
# 33               1649              3577            1516                 359
# 34                NaN               NaN             NaN                 NaN
# 35               1445              3932            1639                 318
# 36                747              2592            1308                 158
# 37                NaN               NaN             NaN                 NaN
# 38                686              2616            1283                 141
# 39                558              1599             708                 117
# 40                531              1130             453                  91
# 41                214               755             287                  90
# 42                204               424             218                  37
# 43                NaN               NaN             NaN                 NaN
# 44                NaN               NaN             NaN                 NaN
# 45              14042             30240           12736                2459
# 46                710              1240             363                  46
# 47               6039             10776            4673                 643
# 48                NaN               NaN             NaN                 NaN
# 49              14042           30239.7           12736             2459.27
#
#    Doctoral degree
# 5             3703
# 6              NaN
# 7              NaN
# 8             2657
# 9               76
# 10              41
# 11              79
# 12             318
# 13             532
# 14             NaN
# 15             NaN
# 16             NaN
# 17            1437
# 18             110
# 19             NaN
# 20             624
# 21              94
# 22             NaN
# 23            1186
# 24             100
# 25             152
# 26             NaN
# 27             NaN
# 28             NaN
# 29            2768
# 30             935
# 31             NaN
# 32            2462
# 33             306
# 34             NaN
# 35             555
# 36             381
# 37             NaN
# 38             344
# 39             266
# 40             148
# 41             102
# 42              76
# 43             NaN
# 44             NaN
# 45            2766
# 46              67
# 47             870
# 48             NaN
# 49         2765.68

# %%
#Munging data so subsets of data are seperated
M_Age_df = Age_df[15:29]

# %%
W_Age_df = Age_df[31:50]

# %%
T_Age_df = Age_df[0:14]

# %%
W_Age_df
# Out:
#                     Age   Total None 1st - 4th grade 5th - 6th grade  \
# 37     ..18 to 24 years   14766   24              17              40
# 38   .25 years and over  108695  456             885            1583
# 39     ..25 to 29 years   10655    5              42              87
# 40     ..30 to 34 years   10594   46              41             122
# 41     ..35 to 39 years    9848   49              72             164
# 42     ..40 to 44 years   10348   29              53             173
# 43     ..45 to 49 years   10520   31              51             128
# 44     ..50 to 54 years   11446   23              77             159
# 45     ..55 to 59 years   10905   36              70             133
# 46     ..60 to 64 years    9635   52              86             121
# 47     ..65 to 69 years    7866   38              96             112
# 48     ..70 to 74 years    5830   33              68             103
# 49  ..75 years and over   11049  114             228             282
#
#    7th - 8th grade 9th grade 10th grade 11th grade High school graduate  \
# 37              79       117        265       1618                 3883
# 38            2043      1772       2051       3319                31522
# 39              96       166        159        348                 2404
# 40             131       224        169        342                 2313
# 41             123       130        178        258                 2173
# 42             103       183        137        287                 2437
# 43             141       157        137        262                 2997
# 44             161       175        179        356                 3385
# 45             156       165        144        296                 3457
# 46             233        87        170        216                 3069
# 47             220       103        195        267                 2578
# 48             125       100        153        191                 2230
# 49             554       282        429        497                 4478
#
#    Some college no degree Associate's degree, occupational  \
# 37                   5937                              350
# 38                  18462                             4943
# 39                   2143                              512
# 40                   1674                              489
# 41                   1601                              498
# 42                   1681                              561
# 43                   1819                              510
# 44                   1985                              542
# 45                   1860                              502
# 46                   1660                              449
# 47                   1438                              341
# 48                   1055                              165
# 49                   1544                              373
#
#    Associate's degree, academic Bachelor's degree Master's degree  \
# 37                          568              1719             135
# 38                         6875             22157            9926
# 39                          730              2977             784
# 40                          718              2677            1307
# 41                          744              2386            1113
# 42                          744              2527            1138
# 43                          714              2398             951
# 44                          872              2287             912
# 45                          783              2094             957
# 46                          576              1639             993
# 47                          393              1141             750
# 48                          201               792             492
# 49                          398              1238             528
#
#    Professional degree Doctoral degree
# 37                  14               2
# 38                1327            1374
# 39                 103              99
# 40                 192             148
# 41                 178             180
# 42                 133             160
# 43                 100             122
# 44                 171             161
# 45                 124             128
# 46                 163             119
# 47                  85             108
# 48                  38              84
# 49                  41              63

# %%
#Here im ploting the munged data
W_Age_Plot = W_Age_df.plot(kind='bar')
#Here im labeling the "tickmarks" or sets of bars on the x axis
labels = [item.get_text() for item in W_Age_Plot.get_xticklabels()]
labels[0] = '18 to 24 years'
labels[1] =  '25 years and over'
labels[2] = '25 to 29 years'
labels[3] = '30 to 34 years'
labels[4] = '35 to 39 years'
labels[5] = '40 to 44 years'
labels[6] = '45 to 49 years'
labels[7] = '50 to 54 years'
labels[8] = '55 to 59 years'
labels[9] = '60 to 64 years'
labels[10] = "65 to 69 years"
labels[11] = "70 to 74 years"
labels[12] = "75 years and over"
W_Age_Plot.set_xticklabels(labels)
plt.show()

# %%
T_Age_Plot = T_Age_df.plot(kind='bar')
labels = [item.get_text() for item in T_Age_Plot.get_xticklabels()]
labels[0] = '18 to 24 years'
labels[1] =  '25 years and over'
labels[2] = '25 to 29 years'
labels[3] = '30 to 34 years'
labels[4] = '35 to 39 years'
labels[5] = '40 to 44 years'
labels[6] = '45 to 49 years'
labels[7] = '50 to 54 years'
labels[8] = '55 to 59 years'
labels[9] = '60 to 64 years'
labels[10] = "65 to 69 years"
labels[11] = "70 to 74 years"
labels[12] = "75 years and over"
T_Age_Plot.set_xticklabels(labels)
plt.show()

# %%
M_Age_Plot = M_Age_df.plot(kind='bar')
labels = [item.get_text() for item in M_Age_Plot.get_xticklabels()]
labels[0] = '18 to 24 years'
labels[1] =  '25 years and over'
labels[2] = '25 to 29 years'
labels[3] = '30 to 34 years'
labels[4] = '35 to 39 years'
labels[5] = '40 to 44 years'
labels[6] = '45 to 49 years'
labels[7] = '50 to 54 years'
labels[8] = '55 to 59 years'
labels[9] = '60 to 64 years'
labels[10] = "65 to 69 years"
labels[11] = "70 to 74 years"
labels[12] = "75 years and over"
M_Age_Plot.set_xticklabels(labels)
plt.show()
