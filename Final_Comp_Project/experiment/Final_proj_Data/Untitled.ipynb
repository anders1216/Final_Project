# %%
#import libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Import data
Educ_By_Age = pd.read_csv('Table 1-01.csv', index_col = None)

# %%
Educ_By_Age
# Out:
#    Table with row headers in column A and column headers in rows 5 through 6  \
# 0   Table 1.  Educational Attainment of the Popula...
# 1   (Numbers in thousands.  Civilian noninstitutio...
# 2                                                 NaN
# 3                                           All Races
# 4                                                 NaN
# 5                                          Both Sexes
# 6                                  .18 years and over
# 7                                    ..18 to 24 years
# 8                                  .25 years and over
# 9                                    ..25 to 29 years
# 10                                   ..30 to 34 years
# 11                                   ..35 to 39 years
# 12                                   ..40 to 44 years
# 13                                   ..45 to 49 years
# 14                                   ..50 to 54 years
# 15                                   ..55 to 59 years
# ...

# %%
#rename columns
Educ_By_Age.columns = [['Age', 'Total', 'None', '1st-4th_grade', '5th_&_6th_grade', '7th_&_8th_grade', '9th_grade', '10th_grade', '11th_grade', 'High_school_graduate', 'Some_college_no_degree', "Associate_degree_occupational", "Associate's_degree_academic", "Bachelor_degree", "Master_degree", 'Professional_degree', 'Doctoral_degree',None,None,None]]

# %%
#sepepate data by gender
Men =Educ_By_Age[4:35]
Women= Educ_By_Age[36:50]

# %%
#here I am trying to make a function to test the lengths of the Men and Women Dataframes to be sure they are
#similar shapes so they can be merged effectively.
#I need help mergergin these two files

# %%
len(Women.Master_degree)
# Out:
# 14

# %%
print(Women.columns[0:10])
# Out:
# Index(['Age', 'Total', 'None', '1st-4th_grade', '5th_&_6th_grade',
#        '7th_&_8th_grade', '9th_grade', '10th_grade', '11th_grade',
#        'High_school_graduate'],
#       dtype='object')

# %%
Women = Women.ix[:,0:17]

# %%
Women.head(n=2)
# Out:
#                    Age   Total None 1st-4th_grade 5th_&_6th_grade  \
# 36  .18 years and over  123461  480           902           1,623
# 37    ..18 to 24 years   14766   24            17              40
#
#    7th_&_8th_grade 9th_grade 10th_grade 11th_grade High_school_graduate  \
# 36           2,122     1,889      2,315      4,937               35,405
# 37              79       117        265      1,618                3,883
#
#    Some_college_no_degree Associate_degree_occupational  \
# 36                 24,399                         5,293
# 37                  5,937                           350
#
#    Associate's_degree_academic Bachelor_degree Master_degree  \
# 36                       7,442          23,876        10,061
# 37                         568           1,719           135
#
#    Professional_degree Doctoral_degree
# 36               1,341           1,376
# 37                  14               2

# %%
Women.ix[:,1] = (Women['Total'].str.extract('([0-9]*),?') + Women['Total'].str.extract(',([0-9]*)')).astype('float')

# %%
for r in Women:
    Women.ix[:,n] = (Women['Total'].str.extract('([0-9]*),?') + Women['Total'].str.extract(',([0-9]*)')).astype('float')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-35e29c37353a> in <module>()
#       1 for r in Women:
# ----> 2     Women.ix[:,n] = (Women['Total'].str.extract('([0-9]*),?') + Women['Total'].str.extract(',([0-9]*)')).astype('float')
#       3
#
# /Users/andershornor/anaconda/lib/python3.4/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2239                 or name in self._metadata
#    2240                 or name in self._accessors):
# -> 2241             return object.__getattribute__(self, name)
#    2242         else:
#    2243             if name in self._info_axis:
#
# /Users/andershornor/anaconda/lib/python3.4/site-packages/pandas/core/base.py in __get__(self, instance, owner)
#     186             # this ensures that Series.str.<method> is well defined
#     187             return self.accessor_cls
# ...

# %%
Women

# %%
Women.head(n=2)

# %%
filename2 = pd.read_excel('Table 1-01.xlsx')

# %%
filename2

# %%
Women.dtypes

# %%
Educ = pd.read_csv('Table 2-01.csv', index_col=None)

# %%
Educ[:80]

# %%
Educ_exel = pd.read_table('Table 1-01.xlsx')

# %%
Age_df.ix[:,1] = (Age_df['Total'].str.extract('([0-9]*),?') + Age_df['Total'].str.extract(',([0-9]*)')).astype('float')
